# %%
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import math
import pandas as pd
from deap import base, creator, tools, algorithms
import logging
import random
import numpy as np
import itertools
import sys
from typing import List, Tuple
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import TransformedTargetRegressor
import os

# pacotes personalizados
import util
from class_manipulate_data import ManipulateData
from class_control_panel import ControlPanel
from ga_K_LightGBM import GA
# Out:
# ga_K_LightGBM - INFO - Módulo util importado com sucesso.

# %%
def generate_combinations(variable_dict):
    """
    Generate all possible combinations from the values of a dictionary of variables.

    Args:
    variable_dict (dict): A dictionary where keys are variable names and values are lists of possible values.

    Returns:
    list: A list of tuples, each containing a combination of values from the input lists.
    """
    # Extract lists of values from the dictionary
    lists = variable_dict.values()
    
    # Generate all possible combinations
    combinations = list(itertools.product(*lists))
    
    return combinations

# %%
def merge_dict_list(dict_list):
    """
    Merge a list of dictionaries into a single dictionary.
    
    Args:
    dict_list (list): A list of dictionaries where each dictionary has a key 'Antecedent'
                      and contains another dictionary with a variable name and its values.

    Returns:
    dict: A single dictionary with variable names as keys and lists of values as values.
    """
    merged_dict = {}
    for item in dict_list:
        for key, value in item.items():
            merged_dict[key] = value
    return merged_dict

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
console_format = logging.Formatter('%(name)s - %(levelname)s - %(message)s')
console_handler = logging.StreamHandler()
console_handler.setFormatter(console_format)
console_handler.setLevel(logging.INFO)
logger.addHandler(console_handler)

file_format = logging.Formatter('%(asctime)s: %(name)s - %(levelname)s - ' +
                                '%(message)s')
log_path = os.path.join(os.getcwd(), 'ga_v2.log')
file_handler = logging.FileHandler(log_path)
file_handler.setFormatter(file_format)
file_handler.setLevel(logging.DEBUG)
logger.addHandler(file_handler)
# endregion

logger.info(util.init())
# Out:
# __main__ - INFO - Módulo util importado com sucesso.

# %%
LENGHT_ROI = 125
manipulate_data = ManipulateData()
path_preprocessing_output = manipulate_data.get_path_preprocessing_output()


control_panel = ControlPanel(rolling_mean=False,
                                 window_mean=None,
                                 use_validation_data=False,
                                 number_units_validation=None,
                                 use_optuna=True,
                                 use_savgol_filter=False,
                                 use_roi=True)

control_panel.set_roi(LENGHT_ROI)

# %%
# entradas selecionadas pelo algoritmo genético
k=3

input_model = GA(k)

output_model = ['RUL']

equipment_name = 'FD001'

 
set_amounts = 9
set_names = ["Extremely Low", "Very Low", "Low", "Medium Low", "Medium", "Medium High", "High", "Very High", "Extremely High"]
# Out:
# ga_K_LightGBM - INFO - ##### K = 3 #####
# ga_K_LightGBM - INFO - Lendo os dados de treino.
# ga_K_LightGBM - INFO - Lendo os dados de teste.
# gen	nevals	avg          	min          	max
# 0  	100   	[26.34931395]	[21.45400564]	[30.34443236]
# 1  	30    	[22.62640337]	[21.45400564]	[23.41847659]
# 2  	30    	[21.51556088]	[20.5904651] 	[22.11512428]
# 3  	30    	[21.04331296]	[20.5904651] 	[21.49009241]
# 4  	30    	[20.84966622]	[20.5904651] 	[21.24430812]
# 5  	30    	[20.71889762]	[20.5904651] 	[20.93579365]
# 6  	30    	[20.60850294]	[20.5904651] 	[20.77084344]
# 7  	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 8  	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 9  	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 10 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 11 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 12 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 13 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 14 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 15 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 16 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 17 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 18 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 19 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 20 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 21 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 22 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 23 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# 24 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# ga_K_LightGBM - INFO - K = 3
# ga_K_LightGBM - INFO - hof: 20.590 << ['sensor_11', 'time', 'sensor_9']
# 25 	30    	[20.5904651] 	[20.5904651] 	[20.5904651]
# sensor_11 time sensor_9

# %%
logger.info("Lendo os dados de treino.")

path_dataset_train = \
    str(path_preprocessing_output.joinpath(f"train_{equipment_name}.parquet"))

df_train = pd.read_parquet(path_dataset_train)
df_train = control_panel.apply_roi(df_train, output_model[0], LENGHT_ROI)

logger.info("Lendo os dados de teste.")

path_dataset_test = \
    str(path_preprocessing_output.joinpath(f"test_{equipment_name}.parquet"))

df_test = pd.read_parquet(path_dataset_test)
df_test = control_panel.apply_roi(df_test, output_model[0], LENGHT_ROI)
# Out:
# __main__ - INFO - Lendo os dados de treino.
# __main__ - INFO - Lendo os dados de teste.

# %%
df_train = df_train[input_model + output_model].copy()

df_test = df_test[input_model + output_model].copy()

# %%
var_linguisticas = []
for input in input_model:
    min_train = df_train[input].min()
    min_test = df_test[input].min()
    if min_test < min_train:
        min_r = min_test
    else:
        min_r = min_train

    max_train = df_train[input].max()
    max_test = df_test[input].max()
    if max_test < max_train:
        max_r = max_train
    else:
        max_r = max_test
    aux = {}
    aux["name"] = input
    aux["min"] = math.floor(min_r) - 1
    aux["max"] = math.ceil(max_r) + 1
    aux["step"] = 0.01
    var_linguisticas.append(aux)

# %%
for var in var_linguisticas:
    var["antecedente"] = ctrl.Antecedent(np.arange(var["min"], var["max"], var["step"]), var["name"])
    var["antecedente"].automf(set_amounts, names=set_names)

RUL = ctrl.Consequent(np.arange(math.floor(df_train[output_model].values.min()),
                                math.ceil(df_train[output_model].values.max()) + 1,
                                0.01),
                                output_model[0],
                                defuzzify_method='centroid')
RUL.automf(set_amounts, names=set_names)

# %%
def manter_regras_com_maior_DR_j(regras):
    antecedentes_para_regras = {}

    # Passo 1: Criar um dicionário mapeando antecedentes para as regras com consequentes diferentes
    for regra in regras:
        antecedentes = tuple(regra['antecedentes'])
        consequente = regra['consequente']
        if antecedentes not in antecedentes_para_regras:
            antecedentes_para_regras[antecedentes] = {'regras': [regra], 'maior_DR_j': regra['DR_j']}
        else:
            antecedentes_para_regras[antecedentes]['regras'].append(regra)
            if regra['DR_j'] > antecedentes_para_regras[antecedentes]['maior_DR_j']:
                antecedentes_para_regras[antecedentes]['maior_DR_j'] = regra['DR_j']

    # Passo 2: Criar uma nova lista de regras com os maiores DR_j
    novas_regras = []
    for antecedentes, info in antecedentes_para_regras.items():
        maior_DR_j = info['maior_DR_j']
        regras_com_maior_DR_j = [regra for regra in info['regras'] if regra['DR_j'] == maior_DR_j]
        novas_regras.extend(regras_com_maior_DR_j)

    return novas_regras

# %%
logger.info("Extraindo as regras")
regras = []
for indice, data in df_train.iterrows():
    DR_j = 1
    regra = {}
    # antecedente
    regra["antecedentes"] = []
    for var in var_linguisticas:
        valor = data[var["name"]]
        grau_max = 0
        conj_max = None
        for conjunto in var["antecedente"].terms:
            grau_pertinencia = fuzz.interp_membership(var["antecedente"].universe, var["antecedente"][conjunto].mf, valor)
            if grau_pertinencia > grau_max:
                grau_max = grau_pertinencia
                conj_max = conjunto
        DR_j = DR_j * grau_max

        regra["antecedentes"].append(var["antecedente"][conj_max])

    # consequente
    valor = data["RUL"]
    grau_max = 0
    conj_max = None
    for conjunto in RUL.terms:
        grau_pertinencia = fuzz.interp_membership(RUL.universe, RUL[conjunto].mf, valor)
        if grau_pertinencia > grau_max:
            grau_max = grau_pertinencia
            conj_max = conjunto
    DR_j = DR_j * grau_max
    regra["DR_j"] = DR_j
    regra["consequente"] = RUL[conj_max]
    regras.append(regra)
# Out:
# __main__ - INFO - Extraindo as regras

# %%
logger.info("Filtrando as regras")
novas_regras = manter_regras_com_maior_DR_j(regras)

# %%
logger.info(f"São {len(novas_regras)} regras após a filtragem.")

# %%
ctrl_rule = []
# Combine os antecedentes usando o operador E ("&")
for regra in novas_regras:
    antecedentes = regra["antecedentes"]
    consequente = regra["consequente"]
    regra_aux = antecedentes[0]
    for antecedente in antecedentes[1:]:
        regra_aux = regra_aux & antecedente

    # Combine o antecedente com o consequente
    # regra_final = regra >> consequente

    # Adicione a regra ao controlador (se necessário)
    ctrl_rule.append(ctrl.Rule(regra_aux, consequente))
# Out:
# __main__ - INFO - Filtrando as regras
# __main__ - INFO - São 92 regras após a filtragem.

# %%
len(ctrl_rule)
# Out:
# 92

# %%
logger.info("Criando o sistema de controle")
sistema_controle = ctrl.ControlSystem(ctrl_rule)
controle = ctrl.ControlSystemSimulation(sistema_controle)

# %%
data = df_train.iloc[0]
# Out:
# __main__ - INFO - Criando o sistema de controle

# %%
def func_rules_activated(data, var_linguisticas, novas_regras):
    rules_activated = {}
        # antecedente
    #rules_activated["antecedentes"] = []
    rules_activated = []
    DR_j = 1
    for var in var_linguisticas:
        valor = data[var["name"]]

        set_activated = {}
        set_activated[var["antecedente"]] = []
        for conjunto in var["antecedente"].terms:
            grau_pertinencia = fuzz.interp_membership(var["antecedente"].universe, var["antecedente"][conjunto].mf, valor)
            if grau_pertinencia > 0:
                set_activated[var["antecedente"]].append(var["antecedente"][conjunto])

        rules_activated.append(set_activated)

    merged_dict = merge_dict_list(rules_activated)

    possible_rules = generate_combinations(merged_dict)
    i = 0
    for nova_regra in novas_regras:
        for possible_rule in possible_rules:
            if possible_rule == tuple(nova_regra["antecedentes"]):
                print(nova_regra)
                i += 1
                
    print(f'{i} regras ativadas')

# %% [markdown]
# # Example: RUL equal 121

# %%
data = df_train.iloc[70]
data
# Out:
# sensor_11      47.30
# time           71.00
# sensor_9     9046.09
# RUL           121.00
# Name: 70, dtype: float64

# %%
for var in var_linguisticas:
    valor = data[var["name"]]
    controle.input[var["name"]] = valor
controle.compute()

# %%
for var in var_linguisticas:
    var["antecedente"].view(sim=controle)

# %%
RUL.view(sim=controle)

# %%
controle.output['RUL']
# Out:
# 112.66702249435025

# %%
func_rules_activated(data, var_linguisticas, novas_regras)
# Out:
# {'antecedentes': [sensor_11[Medium], time[Very Low], sensor_9[Very Low]], 'DR_j': 0.9187549342180452, 'consequente': RUL[Very High]}
# {'antecedentes': [sensor_11[Medium Low], time[Very Low], sensor_9[Very Low]], 'DR_j': 0.65888835462568, 'consequente': RUL[Extremely High]}
# {'antecedentes': [sensor_11[Medium], time[Low], sensor_9[Very Low]], 'DR_j': 0.8987344851307695, 'consequente': RUL[Extremely High]}
# {'antecedentes': [sensor_11[Medium Low], time[Low], sensor_9[Very Low]], 'DR_j': 0.591857289027193, 'consequente': RUL[Extremely High]}
# {'antecedentes': [sensor_11[Medium], time[Very Low], sensor_9[Extremely Low]], 'DR_j': 0.4161155407981475, 'consequente': RUL[Extremely High]}
# {'antecedentes': [sensor_11[Medium], time[Low], sensor_9[Extremely Low]], 'DR_j': 0.42183577193166816, 'consequente': RUL[Extremely High]}
# 6 regras ativadas

# %% [markdown]
# # Example: RUL equal 21

# %%
data = df_train.iloc[170]
data
# Out:
# sensor_11      48.03
# time          171.00
# sensor_9     9042.12
# RUL            21.00
# Name: 170, dtype: float64

# %%
for var in var_linguisticas:
    valor = data[var["name"]]
    controle.input[var["name"]] = valor
controle.compute()

# %%
for var in var_linguisticas:
    var["antecedente"].view(sim=controle)

# %%
RUL.view(sim=controle)

# %%
controle.output['RUL']
# Out:
# 46.89882624326974

# %%
data
# Out:
# sensor_11      48.03
# time          171.00
# sensor_9     9042.12
# RUL            21.00
# Name: 170, dtype: float64

# %%
func_rules_activated(data, var_linguisticas, novas_regras)
# Out:
# {'antecedentes': [sensor_11[Medium], time[Medium Low], sensor_9[Very Low]], 'DR_j': 0.8480680963792372, 'consequente': RUL[High]}
# {'antecedentes': [sensor_11[Medium High], time[Medium Low], sensor_9[Very Low]], 'DR_j': 0.7293121580015164, 'consequente': RUL[Very Low]}
# {'antecedentes': [sensor_11[Medium], time[Medium], sensor_9[Very Low]], 'DR_j': 0.7641504898028771, 'consequente': RUL[Extremely High]}
# {'antecedentes': [sensor_11[Medium High], time[Medium], sensor_9[Very Low]], 'DR_j': 0.8336364120919291, 'consequente': RUL[Extremely Low]}
# {'antecedentes': [sensor_11[Medium High], time[Medium], sensor_9[Extremely Low]], 'DR_j': 0.5252438903629536, 'consequente': RUL[Extremely Low]}
# {'antecedentes': [sensor_11[Medium], time[Medium Low], sensor_9[Extremely Low]], 'DR_j': 0.29089333675850904, 'consequente': RUL[Medium]}
# {'antecedentes': [sensor_11[Medium High], time[Medium Low], sensor_9[Extremely Low]], 'DR_j': 0.42438710745123404, 'consequente': RUL[Extremely Low]}
# {'antecedentes': [sensor_11[Medium], time[Medium], sensor_9[Extremely Low]], 'DR_j': 0.30775112795780724, 'consequente': RUL[Medium Low]}
# 8 regras ativadas

# %% [markdown]
# São oito regras pois é o número máximo de regras que podem ser ativadas na previsão.
#
# 2^3, onde 3 é a quantidade de antecedentes. O número 2 é o número máximo de conjunto que podem ser ativados de uma vez.

# %%
novas_regras
# Out:
# [{'antecedentes': [sensor_11[Medium], time[Extremely Low], sensor_9[Very Low]],
#   'DR_j': 0.8794887060517411,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium Low],
#    time[Extremely Low],
#    sensor_9[Very Low]],
#   'DR_j': 0.7185852277512984,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium], time[Very Low], sensor_9[Very Low]],
#   'DR_j': 0.9187549342180452,
#   'consequente': RUL[Very High]},
#  {'antecedentes': [sensor_11[Medium Low], time[Very Low], sensor_9[Very Low]],
#   'DR_j': 0.65888835462568,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium], time[Low], sensor_9[Very Low]],
#   'DR_j': 0.8987344851307695,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium], time[Medium Low], sensor_9[Very Low]],
#   'DR_j': 0.8480680963792372,
#   'consequente': RUL[High]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium Low],
#    sensor_9[Very Low]],
#   'DR_j': 0.7293121580015164,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium], time[Medium], sensor_9[Very Low]],
#   'DR_j': 0.7641504898028771,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium High], time[Medium], sensor_9[Very Low]],
#   'DR_j': 0.8336364120919291,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium],
#    sensor_9[Extremely Low]],
#   'DR_j': 0.5252438903629536,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium Low], time[Low], sensor_9[Very Low]],
#   'DR_j': 0.591857289027193,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium Low], time[Low], sensor_9[Low]],
#   'DR_j': 0.5525666910984318,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium], time[Low], sensor_9[Low]],
#   'DR_j': 0.8023962101099923,
#   'consequente': RUL[Very High]},
#  {'antecedentes': [sensor_11[Medium Low],
#    time[Medium Low],
#    sensor_9[Very Low]],
#   'DR_j': 0.42766464076185556,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium Low], time[Medium Low], sensor_9[Low]],
#   'DR_j': 0.49913501465774085,
#   'consequente': RUL[Medium High]},
#  {'antecedentes': [sensor_11[Medium], time[Medium Low], sensor_9[Low]],
#   'DR_j': 0.8635292763740792,
#   'consequente': RUL[Medium]},
#  {'antecedentes': [sensor_11[Medium], time[Medium], sensor_9[Low]],
#   'DR_j': 0.8218492652512777,
#   'consequente': RUL[Medium High]},
#  {'antecedentes': [sensor_11[Medium Low], time[Medium], sensor_9[Very Low]],
#   'DR_j': 0.16783836974619787,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium], time[Medium High], sensor_9[Low]],
#   'DR_j': 0.7608638789787795,
#   'consequente': RUL[Very High]},
#  {'antecedentes': [sensor_11[Medium], time[Medium High], sensor_9[Very Low]],
#   'DR_j': 0.7748951553994736,
#   'consequente': RUL[Medium]},
#  {'antecedentes': [sensor_11[Medium High], time[Medium High], sensor_9[Low]],
#   'DR_j': 0.6903462857999255,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium], time[High], sensor_9[Low]],
#   'DR_j': 0.6316728313089398,
#   'consequente': RUL[Medium High]},
#  {'antecedentes': [sensor_11[Medium High], time[High], sensor_9[Low]],
#   'DR_j': 0.7509301176190925,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium], time[High], sensor_9[Medium Low]],
#   'DR_j': 0.41342367468281493,
#   'consequente': RUL[Medium High]},
#  {'antecedentes': [sensor_11[Medium High], time[High], sensor_9[Medium Low]],
#   'DR_j': 0.7421846807989162,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium], time[Very Low], sensor_9[Low]],
#   'DR_j': 0.7539791866939564,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium], time[Medium Low], sensor_9[Medium Low]],
#   'DR_j': 0.6313800985393896,
#   'consequente': RUL[Low]},
#  {'antecedentes': [sensor_11[Medium], time[Medium Low], sensor_9[Medium]],
#   'DR_j': 0.22191639354922124,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium High], time[Medium Low], sensor_9[Medium]],
#   'DR_j': 0.4589276344414303,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium], time[Medium], sensor_9[Medium]],
#   'DR_j': 0.8121626462239955,
#   'consequente': RUL[Low]},
#  {'antecedentes': [sensor_11[Medium High], time[Medium], sensor_9[Medium]],
#   'DR_j': 0.767404299647648,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium],
#    sensor_9[Medium High]],
#   'DR_j': 0.6949242086867243,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium], time[Medium], sensor_9[Medium High]],
#   'DR_j': 0.6890861355104637,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium High], time[Medium], sensor_9[High]],
#   'DR_j': 0.7078534828587667,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium Low],
#    sensor_9[Medium Low]],
#   'DR_j': 0.8712466999595306,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium], time[Medium], sensor_9[Medium Low]],
#   'DR_j': 0.7913602507237326,
#   'consequente': RUL[Medium Low]},
#  {'antecedentes': [sensor_11[Medium], time[Extremely Low], sensor_9[Low]],
#   'DR_j': 0.6144247903396325,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium Low], time[Extremely Low], sensor_9[Low]],
#   'DR_j': 0.6678220287941596,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium Low], time[Very Low], sensor_9[Low]],
#   'DR_j': 0.6826107053151,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium Low], time[Medium], sensor_9[Low]],
#   'DR_j': 0.47462271671119605,
#   'consequente': RUL[Medium]},
#  {'antecedentes': [sensor_11[Medium], time[Medium High], sensor_9[Medium Low]],
#   'DR_j': 0.8523725030311807,
#   'consequente': RUL[Medium Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium High],
#    sensor_9[Medium Low]],
#   'DR_j': 0.6775114158737651,
#   'consequente': RUL[Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium High],
#    sensor_9[Medium]],
#   'DR_j': 0.648330955766071,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium], time[Medium High], sensor_9[Medium]],
#   'DR_j': 0.4141277671963559,
#   'consequente': RUL[Low]},
#  {'antecedentes': [sensor_11[Medium High], time[High], sensor_9[Medium]],
#   'DR_j': 0.5961320428494219,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium], time[High], sensor_9[Medium]],
#   'DR_j': 0.26255788711897915,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium High], time[High], sensor_9[Medium High]],
#   'DR_j': 0.6116353187570088,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium], time[Very Low], sensor_9[Extremely Low]],
#   'DR_j': 0.4161155407981475,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium High], time[Very Low], sensor_9[Very Low]],
#   'DR_j': 0.33381265173689373,
#   'consequente': RUL[High]},
#  {'antecedentes': [sensor_11[Medium High], time[Low], sensor_9[Very Low]],
#   'DR_j': 0.5089118029711226,
#   'consequente': RUL[Medium High]},
#  {'antecedentes': [sensor_11[Medium], time[Low], sensor_9[Extremely Low]],
#   'DR_j': 0.42183577193166816,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium],
#    time[Medium Low],
#    sensor_9[Extremely Low]],
#   'DR_j': 0.29089333675850904,
#   'consequente': RUL[Medium]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium Low],
#    sensor_9[Extremely Low]],
#   'DR_j': 0.42438710745123404,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High], time[Medium], sensor_9[Low]],
#   'DR_j': 0.6699212316747416,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium Low],
#    time[Medium Low],
#    sensor_9[Medium Low]],
#   'DR_j': 0.3928814433347983,
#   'consequente': RUL[Medium]},
#  {'antecedentes': [sensor_11[Medium High], time[Medium], sensor_9[Very High]],
#   'DR_j': 0.5203123935046702,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium],
#    sensor_9[Extremely High]],
#   'DR_j': 0.4381559890275051,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High], time[Medium], sensor_9[Medium Low]],
#   'DR_j': 0.7159594828380594,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium High],
#    sensor_9[Medium High]],
#   'DR_j': 0.6402195161945818,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium],
#    time[Extremely Low],
#    sensor_9[Extremely Low]],
#   'DR_j': 0.40449432775230343,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium High], time[Medium Low], sensor_9[Low]],
#   'DR_j': 0.5860552513641751,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium High], time[Low], sensor_9[Low]],
#   'DR_j': 0.33832410822658443,
#   'consequente': RUL[Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium High],
#    sensor_9[Very Low]],
#   'DR_j': 0.6903791118664963,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High], time[High], sensor_9[High]],
#   'DR_j': 0.4039591996981622,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium], time[Medium], sensor_9[High]],
#   'DR_j': 0.33541010736418797,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[High], time[Medium], sensor_9[Low]],
#   'DR_j': 0.2739204490390388,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[High], time[Medium], sensor_9[Medium High]],
#   'DR_j': 0.3921970218168841,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High], time[Low], sensor_9[Extremely Low]],
#   'DR_j': 0.40228741565027004,
#   'consequente': RUL[Low]},
#  {'antecedentes': [sensor_11[Medium High], time[High], sensor_9[Very Low]],
#   'DR_j': 0.632189331096301,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium],
#    time[Medium High],
#    sensor_9[Medium High]],
#   'DR_j': 0.42511214480511844,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium], time[Medium High], sensor_9[High]],
#   'DR_j': 0.4309895577413623,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium High], time[Medium High], sensor_9[High]],
#   'DR_j': 0.4181999595798942,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium High],
#    sensor_9[Very High]],
#   'DR_j': 0.7602016038216697,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium], time[Medium High], sensor_9[Very High]],
#   'DR_j': 0.29498696373650246,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium High],
#    sensor_9[Extremely High]],
#   'DR_j': 0.4179132905558292,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Extremely Low],
#    sensor_9[Very Low]],
#   'DR_j': 0.28444078169860204,
#   'consequente': RUL[Extremely High]},
#  {'antecedentes': [sensor_11[Medium High], time[Very High], sensor_9[Low]],
#   'DR_j': 0.7219011465465037,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium], time[High], sensor_9[Very Low]],
#   'DR_j': 0.5743603338306067,
#   'consequente': RUL[High]},
#  {'antecedentes': [sensor_11[Medium], time[Very High], sensor_9[Low]],
#   'DR_j': 0.20533280730226539,
#   'consequente': RUL[Medium]},
#  {'antecedentes': [sensor_11[Medium], time[Very High], sensor_9[Very Low]],
#   'DR_j': 0.3164763110100915,
#   'consequente': RUL[Medium Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Very High],
#    sensor_9[Very Low]],
#   'DR_j': 0.47957679262784586,
#   'consequente': RUL[Medium Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Extremely High],
#    sensor_9[Very Low]],
#   'DR_j': 0.6501592273008653,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Extremely High],
#    sensor_9[Low]],
#   'DR_j': 0.18830162695903807,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium], time[Medium], sensor_9[Extremely Low]],
#   'DR_j': 0.30775112795780724,
#   'consequente': RUL[Medium Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Medium High],
#    sensor_9[Extremely Low]],
#   'DR_j': 0.7004344209378491,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[Medium],
#    time[Medium High],
#    sensor_9[Extremely Low]],
#   'DR_j': 0.22658979461500917,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium], time[Very High], sensor_9[Medium Low]],
#   'DR_j': 0.35398173675087063,
#   'consequente': RUL[Medium Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Very High],
#    sensor_9[Medium Low]],
#   'DR_j': 0.4789540423409324,
#   'consequente': RUL[Low]},
#  {'antecedentes': [sensor_11[Medium High], time[Very High], sensor_9[Medium]],
#   'DR_j': 0.4482121092968692,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium], time[Very High], sensor_9[Medium]],
#   'DR_j': 0.24069130043174977,
#   'consequente': RUL[Very Low]},
#  {'antecedentes': [sensor_11[Medium High],
#    time[Extremely High],
#    sensor_9[Medium]],
#   'DR_j': 0.2663675322722165,
#   'consequente': RUL[Extremely Low]},
#  {'antecedentes': [sensor_11[High], time[Medium], sensor_9[Very Low]],
#   'DR_j': 0.3581654297474454,
#   'consequente': RUL[Extremely Low]}]
